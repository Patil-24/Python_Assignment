# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup


my_url = 'https://www.newegg.com/Desktop-Graphics-Cards/SubCategory/ID-48?Tid=7709'
uclient = uReq(my_url)
page_html = uclient.read()
uclient.close()
page_soup = soup(page_html,"html.parser")

containers = page_soup.findAll("div", {"class":"item-container"})

file_name = "product.csv"
f = open(file_name, "w")

headers = "brand , shipping , price \n"
f.write(headers)



for container in containers:
    brand = container.a.img["title"]

    

    shipping_container = container.findAll("li", {"class":"price-ship"})
    shipping = shipping_container[0].text.strip()

    price_list = container.findAll("li", {"class":"price-current"})
    price = price_list[0].text.strip().replace("|","").replace('\r', '').replace('\n', '')


    print("brand : " + brand)
    # print("product_name : " + product_name)
    print("shipping :  " + shipping)
    print("price : " + price)
    print("_____________________________________________________________________________________________________________")


    f.write(brand.replace(",","|") + "," + shipping + "," + price.replace(",",".") + "\n")

f.close()
# Out:
# brand : GIGABYTE GeForce RTX 3090 GAMING OC 24G Video Card, GV-N3090GAMING OC-24GD
# shipping :  $9.99 Shipping
# price : $1,699.99 (16 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Radeon RX 6900 XT GAMING OC Video Card, GV-R69XTGAMING OC-16GD
# shipping :  Free Shipping
# price : $999.99 (12 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASUS ROG Strix GeForce RTX 3050 8GB GDDR6 PCI Express 4.0 Video Card ROG-STRIX-RTX3050-O8G-GAMING
# shipping :  $9.99 Shipping
# price : $429.99 (23 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE GeForce RTX 3050 GAMING OC 8G Graphics Card, 3x WINDFORCE Fans, 8GB GDDR6 128-bit GDDR6, GV-N3050GAMING OC-8GD Video Card
# shipping :  $9.99 Shipping
# price : $379.99 (21 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE GAMING OC Radeon RX 6500 XT 4GB GDDR6 PCI Express 4.0 ATX Video Card GV-R65XTGAMING OC-4GD
# shipping :  Free Shipping
# price : $229.99 (9 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASRock OC Formula Radeon RX 6900 XT 16GB GDDR6 PCI Express 4.0 ATX Video Card RX6900XT OCF 16G
# shipping :  Free Shipping
# price : $1,149.99 (3 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Radeon RX 6700 XT GAMING OC 12G Graphics Card, WINDFORCE 3X Cooling System, 12GB 192-bit GDDR6, GV-R67XTGAMING OC-12GD Video Card
# shipping :  Free Shipping
# price : $624.99 (17 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Gaming Radeon RX 6700 XT 12GB GDDR6 PCI Express 4.0 Video Card RX 6700 XT GAMING X 12G
# shipping :  Free Shipping
# price : $539.99 (3 Offers)–
# _____________________________________________________________________________________________________________
# brand : XFX SPEEDSTER SWFT210 Radeon RX 6600 XT 8GB GDDR6 PCI Express 4.0 Core Gaming Graphics Card, AMD RDNA 2 RX-66XT8DFDQ
# shipping :  Free Shipping
# price : $399.99 (6 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming OC GeForce RTX 3060 12GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3060GAMING OC-12GD (rev. 2.0) (LHR)
# shipping :  $9.99 Shipping
# price : $439.99 (14 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
# shipping :  Free Shipping
# price : $869.99 (8 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Eagle GeForce RTX 3070 Ti 8GB GDDR6X PCI Express 4.0 ATX Video Card GV-N307TEAGLE OC-8GD
# shipping :  Free Shipping
# price : $699.99 (10 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3050 8GB GDDR6 PCI Express 4.0 Video Card RTX 3050 Ventus 2X 8G OC
# shipping :  $9.99 Shipping
# price : $329.99 (11 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Mech Radeon RX 6700 XT 12GB GDDR6 PCI Express 4.0 Video Card RX 6700 XT MECH 2X 12G
# shipping :  Free Shipping
# price : $499.99 (9 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
# shipping :  Free Shipping
# price : $889.99 (20 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3090 FTW3 ULTRA GAMING Video Card, 24G-P5-3987-KR, 24GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# shipping :  Free Shipping
# price : $1,799.99 (12 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3070 Ti FTW3 ULTRA GAMING Video Card, 08G-P5-3797-KL, 8GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# shipping :  Free Shipping
# price : $759.99 (11 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TGAMING OC-12GD
# shipping :  Free Shipping
# price : $1,199.99 (32 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Gaming GeForce RTX 3070 Ti 8GB GDDR6X PCI Express 4.0 Video Card RTX 3070 Ti Gaming X Trio 8G
# shipping :  Free Shipping
# price : $809.99 (27 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $899.99 (11 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming GeForce RTX 3070 Ti 8GB GDDR6X PCI Express 4.0 ATX Video Card GV-N307TGAMING OC-8GD
# shipping :  Free Shipping
# price : $699.99 (24 Offers)–
# _____________________________________________________________________________________________________________
# brand : SAPPHIRE PULSE AMD Radeon RX 6800 XT Gaming Graphics Card with 16GB GDDR6, AMD RDNA 2 (SKU#11304-03-20G)
# shipping :  $9.99 Shipping
# price : $849.00 (12 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3060 Ti 8GB GDDR6 PCI Express 4.0 Video Card RTX 3060 Ti VENTUS 2X 8G OCV1 LHR
# shipping :  Free Shipping
# price : $652.38 (15 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3080 12GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 12G OC LHR
# shipping :  Free Shipping
# price : $999.99 (11 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Radeon RX 6600 EAGLE 8G Graphics Card, WINDFORCE 3X Cooling System, 8GB 128-bit GDDR6, GV-R66EAGLE-8GD Video Card
# shipping :  Free Shipping
# price : $339.99 (6 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Mech Radeon RX 6600 8GB PCI Express 4.0 Video Card RX 6600 MECH 2X 8G
# shipping :  Free Shipping
# price : $379.99 (17 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASRock Radeon RX 6700 XT Challenger D Gaming Graphic Card, 12GB GDDR6 VRAM, AMD RDNA2 (RX6700XT CLD 12G)
# shipping :  Free Shipping
# price : $498.99 –
# _____________________________________________________________________________________________________________
# brand : ASRock Radeon RX 6600 8GB PCI Express 4.0 Video Card RX6600 CLD 8G
# shipping :  Free Shipping
# price : $335.99 –
# _____________________________________________________________________________________________________________
# brand : XFX SPEEDSTER SWFT309 AMD Radeon RX 6700 XT CORE Gaming Graphics Card with 12GB GDDR6 HDMI 3xDP, AMD RDNA 2 (RX-67XTYJFDV)
# shipping :  Free Shipping
# price : $529.99 (3 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# shipping :  Free Shipping
# price : $1,299.99 (16 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3090 Ti FTW3 ULTRA GAMING, 24G-P5-4985-KR, 24GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, Includes eLeash
# shipping :  Free Shipping
# price : $2,199.99 –
# _____________________________________________________________________________________________________________
# brand : ASUS GeForce RTX 2060 Overclocked 6G GDDR6 Dual-Fan EVO Edition VR Ready HDMI DisplayPort DVI Graphics Card (DUAL-RTX2060-O6G-EVO)
# shipping :  Free Shipping
# price : $389.99 (33 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming OC GeForce RTX 3060 Ti 8GB GDDR6 PCI Express 4.0 ATX Video Card GV-N306TGAMING OC-8GD REV 2.0 (LHR)
# shipping :  Free Shipping
# price : $589.99 (13 Offers)–
# _____________________________________________________________________________________________________________
# brand : Yeston Radeon RX6700XT 12GB D6 GDDR6 192bit 7nm Desktop computer PC Video Graphics Cards support PCI-Express 4.0 3*DP+1*HDMI-compatible   RGB light effect Fragrant graphics card
# shipping :  Free Shipping
# price : $799.00 –
# _____________________________________________________________________________________________________________
# brand : MSI Gaming GeForce RTX 3090 24GB GDDR6X PCI Express 4.0 SLI Support Video Card RTX 3090 GAMING X TRIO 24G
# shipping :  Free Shipping
# price : $1,859.99 (16 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE AORUS GeForce RTX 3060 ELITE 12GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3060AORUS E-12GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $519.99 (13 Offers)–
# _____________________________________________________________________________________________________________
